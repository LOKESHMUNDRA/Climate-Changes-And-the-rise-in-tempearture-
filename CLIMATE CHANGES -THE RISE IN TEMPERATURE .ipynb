# %% [markdown]
# ### Some people say climate changes is one of the biggest threat of our age . I am turning some data to have a look on this .
#
# ### Even more than with other data sets that Kaggle has featured, there’s a huge amount of data cleaning and preparation that goes into putting together a long-time study of climate trends. Early data was collected by technicians using mercury thermometers, where any variation in the visit time impacted measurements. In the 1940s, the construction of airports caused many weather stations to be moved. In the 1980s, there was a move to electronic thermometers that are said to have a cooling bias.
#
#
# ### In this analysis i will over veiw some key things on climate changes

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Reading the dataset

# %%
temp = pd.read_csv("GlobalTemperatures.csv", parse_dates = ["dt"],index_col = "dt")
temp.head()
# Out:
#             LandAverageTemperature  LandAverageTemperatureUncertainty  \
# dt
# 1750-01-01                   3.034                              3.574
# 1750-02-01                   3.083                              3.702
# 1750-03-01                   5.626                              3.076
# 1750-04-01                   8.490                              2.451
# 1750-05-01                  11.573                              2.072
#
#             LandMaxTemperature  LandMaxTemperatureUncertainty  \
# dt
# 1750-01-01                 NaN                            NaN
# 1750-02-01                 NaN                            NaN
# 1750-03-01                 NaN                            NaN
# 1750-04-01                 NaN                            NaN
# 1750-05-01                 NaN                            NaN
#
#             LandMinTemperature  LandMinTemperatureUncertainty  \
# dt
# 1750-01-01                 NaN                            NaN
# ...

# %%
temp.tail()
# Out:
#             LandAverageTemperature  LandAverageTemperatureUncertainty  \
# dt
# 2015-08-01                  14.755                              0.072
# 2015-09-01                  12.999                              0.079
# 2015-10-01                  10.801                              0.102
# 2015-11-01                   7.433                              0.119
# 2015-12-01                   5.518                              0.100
#
#             LandMaxTemperature  LandMaxTemperatureUncertainty  \
# dt
# 2015-08-01              20.699                          0.110
# 2015-09-01              18.845                          0.088
# 2015-10-01              16.450                          0.059
# 2015-11-01              12.892                          0.093
# 2015-12-01              10.725                          0.154
#
#             LandMinTemperature  LandMinTemperatureUncertainty  \
# dt
# 2015-08-01               9.005                          0.170
# ...

# %% [markdown]
# ### Describing the dataset statistiscally and elimating the null dataset

# %%
temp.describe()
# Out:
#        LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count             3180.000000                        3180.000000
# mean                 8.374731                           0.938468
# std                  4.381310                           1.096440
# min                 -2.080000                           0.034000
# 25%                  4.312000                           0.186750
# 50%                  8.610500                           0.392000
# 75%                 12.548250                           1.419250
# max                 19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# std              4.309579                       0.583203            4.155835
# ...

# %%
temp.shape
# Out:
# (3192, 8)

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3192 entries, 1750-01-01 to 2015-12-01
# Data columns (total 8 columns):
# LandAverageTemperature                       3180 non-null float64
# LandAverageTemperatureUncertainty            3180 non-null float64
# LandMaxTemperature                           1992 non-null float64
# LandMaxTemperatureUncertainty                1992 non-null float64
# LandMinTemperature                           1992 non-null float64
# LandMinTemperatureUncertainty                1992 non-null float64
# LandAndOceanAverageTemperature               1992 non-null float64
# LandAndOceanAverageTemperatureUncertainty    1992 non-null float64
# dtypes: float64(8)
# memory usage: 224.4 KB

# %%
temp.isna().sum()
# Out:
# LandAverageTemperature                         12
# LandAverageTemperatureUncertainty              12
# LandMaxTemperature                           1200
# LandMaxTemperatureUncertainty                1200
# LandMinTemperature                           1200
# LandMinTemperatureUncertainty                1200
# LandAndOceanAverageTemperature               1200
# LandAndOceanAverageTemperatureUncertainty    1200
# dtype: int64

# %%
temp.index
# Out:
# DatetimeIndex(['1750-01-01', '1750-02-01', '1750-03-01', '1750-04-01',
#                '1750-05-01', '1750-06-01', '1750-07-01', '1750-08-01',
#                '1750-09-01', '1750-10-01',
#                ...
#                '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01',
#                '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01',
#                '2015-11-01', '2015-12-01'],
#               dtype='datetime64[ns]', name='dt', length=3192, freq=None)

# %% [markdown]
# ### Finding the correlation bwtween the features

# %%
sns.heatmap(temp.corr())

# %%
for itr in temp.columns:
    temp.plot(y = [itr],figsize = [20,10])

# %%
temp.plot(figsize = [20,10],fontsize = 10)

# %% [markdown]
# ### Finding the relation climate changes  and effect of temperature country wise

# %%
country_temp  = pd.read_csv("GlobalLandTemperaturesByCountry.csv")

# %%
country_temp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
country_temp.tail()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 577457  Zimbabwe
# 577458  Zimbabwe
# 577459  Zimbabwe
# 577460  Zimbabwe
# 577461  Zimbabwe

# %% [markdown]
# ### Describing the dataset  statistically and elimating  null dataset

# %%
country_temp.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count       544811.000000                  545550.000000
# mean            17.193354                       1.019057
# std             10.953966                       1.201930
# min            -37.658000                       0.052000
# 25%             10.025000                       0.323000
# 50%             20.901000                       0.571000
# 75%             25.814000                       1.206000
# max             38.842000                      15.003000

# %%
country_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 577462 entries, 0 to 577461
# Data columns (total 4 columns):
# dt                               577462 non-null object
# AverageTemperature               544811 non-null float64
# AverageTemperatureUncertainty    545550 non-null float64
# Country                          577462 non-null object
# dtypes: float64(2), object(2)
# memory usage: 17.6+ MB

# %%
country_temp.shape
# Out:
# (577462, 4)

# %%
country_temp.isna().sum()
# Out:
# dt                                   0
# AverageTemperature               32651
# AverageTemperatureUncertainty    31912
# Country                              0
# dtype: int64

# %%
ax = country_temp.groupby(['dt'])['AverageTemperature'].last().sort_values(ascending=False).head(10).sort_values().plot(kind='barh')
ax.set_xlabel('avg_temp')
plt.title("Datawise Highest Temperature ",fontsize = 10 )
# Out:
# Text(0.5, 1.0, 'Datawise Highest Temperature ')

# %%
ax = country_temp.groupby(['Country'])['AverageTemperature'].last().sort_values(ascending=False).head(10).sort_values().plot(kind='barh')
ax.set_xlabel('avg_temp')
plt.title("Datawise Highest Temperature ",fontsize = 10 )
# Out:
# Text(0.5, 1.0, 'Datawise Highest Temperature ')

# %% [markdown]
# ### Global land temperature state wise

# %%
df_states = pd.read_csv("GlobalLandTemperaturesByState.csv")
df_states.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil
# 5  1855-10-01              25.442                          1.179  Acre  Brazil
# 6  1855-11-01              25.400                          1.064  Acre  Brazil
# 7  1855-12-01              24.100                          1.718  Acre  Brazil
# 8  1856-01-01              25.814                          1.159  Acre  Brazil
# 9  1856-02-01              24.658                          1.147  Acre  Brazil

# %%
df_states.tail(10)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 645665  2012-12-01               6.633                          0.437
# 645666  2013-01-01               5.120                          0.393
# 645667  2013-02-01               7.867                          0.490
# 645668  2013-03-01              12.116                          0.345
# 645669  2013-04-01              15.710                          0.461
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
# 645674  2013-09-01                 NaN                            NaN
#
#            State Country
# 645665  Zhejiang   China
# 645666  Zhejiang   China
# 645667  Zhejiang   China
# 645668  Zhejiang   China
# 645669  Zhejiang   China
# 645670  Zhejiang   China
# ...

# %%
df_states.isna().sum()
# Out:
# dt                                   0
# AverageTemperature               25648
# AverageTemperatureUncertainty    25648
# State                                0
# Country                              0
# dtype: int64

# %%
states = df_states[df_states['Country']=='India']
states = states.groupby('State')['AverageTemperature'].mean().reset_index()
states.sort_values('AverageTemperature', inplace = True)
states = states[:10]
states.plot(kind = 'bar', x = 'State', y = 'AverageTemperature' ,title  = 'Top 10 Coolest City', color = 'deepskyblue')

# %%
states = df_states[df_states['Country']=='India']
states = states.groupby('State')['AverageTemperature'].mean().reset_index()
states.sort_values('AverageTemperature', inplace = True,ascending = False)
states = states[:10]
states.plot(kind = 'bar', x = 'State', y = 'AverageTemperature' ,title  = 'Top 10 Hotest City', color = 'deepskyblue')
